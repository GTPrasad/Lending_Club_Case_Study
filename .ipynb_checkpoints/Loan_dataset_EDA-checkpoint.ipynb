# %% [markdown]
# ### Import required libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from datetime import datetime
import missingno as msno

# %% [markdown]
# ### Loading loan dataset to pandas

# %%
data = pd.read_csv('loan.csv', index_col=0)
data
# Out:
# C:\Users\gtpra\AppData\Local\Temp\ipykernel_24496\3840341585.py:1: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('loan.csv', index_col=0)
#          member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# id
# 1077501    1296599       5000         5000           4975.0   36 months
# 1077430    1314167       2500         2500           2500.0   60 months
# 1077175    1313524       2400         2400           2400.0   36 months
# 1076863    1277178      10000        10000          10000.0   36 months
# 1075358    1311748       3000         3000           3000.0   60 months
# ...            ...        ...          ...              ...         ...
# 92187        92174       2500         2500           1075.0   36 months
# 90665        90607       8500         8500            875.0   36 months
# 90395        90390       5000         5000           1325.0   36 months
# 90376        89243       5000         5000            650.0   36 months
# 87023        86999       7500         7500            800.0   36 months
#
#         int_rate  installment grade sub_grade                   emp_title  \
# id
# 1077501   10.65%       162.87     B        B2                         NaN
# 1077430   15.27%        59.83     C        C4                       Ryder
# 1077175   15.96%        84.33     C        C5                         NaN
# 1076863   13.49%       339.31     C        C1         AIR RESOURCES BOARD
# 1075358   12.69%        67.79     B        B5    University Medical Group
# ...          ...          ...   ...       ...                         ...
# 92187      8.07%        78.42     A        A4             FiSite Research
# 90665     10.28%       275.38     C        C1  Squarewave Solutions, Ltd.
# 90395      8.07%       156.84     A        A4                         NaN
# 90376      7.43%       155.38     A        A2                         NaN
# 87023     13.75%       255.43     E        E2            Evergreen Center
#
#          ... num_tl_90g_dpd_24m num_tl_op_past_12m  pct_tl_nvr_dlq  \
# id       ...
# 1077501  ...                NaN                NaN             NaN
# 1077430  ...                NaN                NaN             NaN
# 1077175  ...                NaN                NaN             NaN
# 1076863  ...                NaN                NaN             NaN
# 1075358  ...                NaN                NaN             NaN
# ...      ...                ...                ...             ...
# 92187    ...                NaN                NaN             NaN
# 90665    ...                NaN                NaN             NaN
# 90395    ...                NaN                NaN             NaN
# 90376    ...                NaN                NaN             NaN
# 87023    ...                NaN                NaN             NaN
#
#         percent_bc_gt_75 pub_rec_bankruptcies tax_liens tot_hi_cred_lim  \
# id
# 1077501              NaN                  0.0       0.0             NaN
# 1077430              NaN                  0.0       0.0             NaN
# 1077175              NaN                  0.0       0.0             NaN
# 1076863              NaN                  0.0       0.0             NaN
# 1075358              NaN                  0.0       0.0             NaN
# ...                  ...                  ...       ...             ...
# 92187                NaN                  NaN       NaN             NaN
# 90665                NaN                  NaN       NaN             NaN
# 90395                NaN                  NaN       NaN             NaN
# 90376                NaN                  NaN       NaN             NaN
# 87023                NaN                  NaN       NaN             NaN
#
#         total_bal_ex_mort total_bc_limit total_il_high_credit_limit
# id
# 1077501               NaN            NaN                        NaN
# 1077430               NaN            NaN                        NaN
# 1077175               NaN            NaN                        NaN
# 1076863               NaN            NaN                        NaN
# 1075358               NaN            NaN                        NaN
# ...                   ...            ...                        ...
# 92187                 NaN            NaN                        NaN
# 90665                 NaN            NaN                        NaN
# 90395                 NaN            NaN                        NaN
# 90376                 NaN            NaN                        NaN
# 87023                 NaN            NaN                        NaN
#
# [39717 rows x 110 columns]

# %% [markdown]
# ### There is a Dtypewarning on column 47 lets see what is it

# %%
data.iloc[:, 46].head()
# Out:
# id
# 1077501       NaN
# 1077430       NaN
# 1077175       NaN
# 1076863       NaN
# 1075358    Jun-16
# Name: next_pymnt_d, dtype: object

# %%
data.iloc[:, 46].value_counts()
# Out:
# Jun-16    1125
# Jul-16      15
# Name: next_pymnt_d, dtype: int64

# %%
data.isna().sum()
# Out:
# member_id                         0
# loan_amnt                         0
# funded_amnt                       0
# funded_amnt_inv                   0
# term                              0
#                               ...
# tax_liens                        39
# tot_hi_cred_lim               39717
# total_bal_ex_mort             39717
# total_bc_limit                39717
# total_il_high_credit_limit    39717
# Length: 110, dtype: int64

# %%
(data.isna().sum()==39717).value_counts()
# Out:
# False    56
# True     54
# dtype: int64

# %% [markdown]
# ### So there are 54 columns with all missing values, Lets drop them!

# %%
data.dropna(axis=1, how='all', inplace=True)

# %%
data.shape
# Out:
# (39717, 56)

# %% [markdown]
# ### Drop rows with all missing values

# %%
data.dropna(axis=0, how='all', inplace=True)

# %%
data.shape
# Out:
# (39717, 56)

# %% [markdown]
# ### Now Lets see what is the percentage of missing values in remaining rows

# %%
(data.isna().sum()/data.shape[0])*100
# Out:
# member_id                      0.000000
# loan_amnt                      0.000000
# funded_amnt                    0.000000
# funded_amnt_inv                0.000000
# term                           0.000000
# int_rate                       0.000000
# installment                    0.000000
# grade                          0.000000
# sub_grade                      0.000000
# emp_title                      6.191303
# emp_length                     2.706650
# home_ownership                 0.000000
# annual_inc                     0.000000
# verification_status            0.000000
# issue_d                        0.000000
# loan_status                    0.000000
# pymnt_plan                     0.000000
# url                            0.000000
# desc                          32.580507
# purpose                        0.000000
# title                          0.027696
# zip_code                       0.000000
# addr_state                     0.000000
# dti                            0.000000
# delinq_2yrs                    0.000000
# earliest_cr_line               0.000000
# inq_last_6mths                 0.000000
# mths_since_last_delinq        64.662487
# mths_since_last_record        92.985372
# open_acc                       0.000000
# pub_rec                        0.000000
# revol_bal                      0.000000
# revol_util                     0.125891
# total_acc                      0.000000
# initial_list_status            0.000000
# out_prncp                      0.000000
# out_prncp_inv                  0.000000
# total_pymnt                    0.000000
# total_pymnt_inv                0.000000
# total_rec_prncp                0.000000
# total_rec_int                  0.000000
# total_rec_late_fee             0.000000
# recoveries                     0.000000
# collection_recovery_fee        0.000000
# last_pymnt_d                   0.178765
# last_pymnt_amnt                0.000000
# next_pymnt_d                  97.129693
# last_credit_pull_d             0.005036
# collections_12_mths_ex_med     0.140998
# policy_code                    0.000000
# application_type               0.000000
# acc_now_delinq                 0.000000
# chargeoff_within_12_mths       0.140998
# delinq_amnt                    0.000000
# pub_rec_bankruptcies           1.754916
# tax_liens                      0.098195
# dtype: float64

# %%
single_valued_columns_list = []
for i in data.columns:
    if data[i].value_counts().shape[0]<2:
        print(i, ' : ', data[i].unique())
        single_valued_columns_list.append(i)
# Out:
# pymnt_plan  :  ['n']
# initial_list_status  :  ['f']
# collections_12_mths_ex_med  :  [ 0. nan]
# policy_code  :  [1]
# application_type  :  ['INDIVIDUAL']
# acc_now_delinq  :  [0]
# chargeoff_within_12_mths  :  [ 0. nan]
# delinq_amnt  :  [0]
# tax_liens  :  [ 0. nan]

# %%
data[single_valued_columns_list]
# Out:
#         pymnt_plan initial_list_status  collections_12_mths_ex_med  \
# id
# 1077501          n                   f                         0.0
# 1077430          n                   f                         0.0
# 1077175          n                   f                         0.0
# 1076863          n                   f                         0.0
# 1075358          n                   f                         0.0
# ...            ...                 ...                         ...
# 92187            n                   f                         NaN
# 90665            n                   f                         NaN
# 90395            n                   f                         NaN
# 90376            n                   f                         NaN
# 87023            n                   f                         NaN
#
#          policy_code application_type  acc_now_delinq  \
# id
# 1077501            1       INDIVIDUAL               0
# 1077430            1       INDIVIDUAL               0
# 1077175            1       INDIVIDUAL               0
# 1076863            1       INDIVIDUAL               0
# 1075358            1       INDIVIDUAL               0
# ...              ...              ...             ...
# 92187              1       INDIVIDUAL               0
# 90665              1       INDIVIDUAL               0
# 90395              1       INDIVIDUAL               0
# 90376              1       INDIVIDUAL               0
# 87023              1       INDIVIDUAL               0
#
#          chargeoff_within_12_mths  delinq_amnt  tax_liens
# id
# 1077501                       0.0            0        0.0
# 1077430                       0.0            0        0.0
# 1077175                       0.0            0        0.0
# 1076863                       0.0            0        0.0
# 1075358                       0.0            0        0.0
# ...                           ...          ...        ...
# 92187                         NaN            0        NaN
# 90665                         NaN            0        NaN
# 90395                         NaN            0        NaN
# 90376                         NaN            0        NaN
# 87023                         NaN            0        NaN
#
# [39717 rows x 9 columns]

# %% [markdown]
# ### Droping columns which are irrelevent for analysis

# %%
data.drop(['pymnt_plan','initial_list_status','policy_code','application_type','acc_now_delinq','delinq_amnt'], axis=1, inplace=True)

# %%
data.head()
# Out:
#          member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# id
# 1077501    1296599       5000         5000           4975.0   36 months
# 1077430    1314167       2500         2500           2500.0   60 months
# 1077175    1313524       2400         2400           2400.0   36 months
# 1076863    1277178      10000        10000          10000.0   36 months
# 1075358    1311748       3000         3000           3000.0   60 months
#
#         int_rate  installment grade sub_grade                 emp_title  ...  \
# id                                                                       ...
# 1077501   10.65%       162.87     B        B2                       NaN  ...
# 1077430   15.27%        59.83     C        C4                     Ryder  ...
# 1077175   15.96%        84.33     C        C5                       NaN  ...
# 1076863   13.49%       339.31     C        C1       AIR RESOURCES BOARD  ...
# 1075358   12.69%        67.79     B        B5  University Medical Group  ...
#
#         recoveries collection_recovery_fee  last_pymnt_d last_pymnt_amnt  \
# id
# 1077501       0.00                    0.00        Jan-15          171.62
# 1077430     117.08                    1.11        Apr-13          119.66
# 1077175       0.00                    0.00        Jun-14          649.91
# 1076863       0.00                    0.00        Jan-15          357.48
# 1075358       0.00                    0.00        May-16           67.79
#
#         next_pymnt_d last_credit_pull_d collections_12_mths_ex_med  \
# id
# 1077501          NaN             May-16                        0.0
# 1077430          NaN             Sep-13                        0.0
# 1077175          NaN             May-16                        0.0
# 1076863          NaN             Apr-16                        0.0
# 1075358       Jun-16             May-16                        0.0
#
#         chargeoff_within_12_mths pub_rec_bankruptcies tax_liens
# id
# 1077501                      0.0                  0.0       0.0
# 1077430                      0.0                  0.0       0.0
# 1077175                      0.0                  0.0       0.0
# 1076863                      0.0                  0.0       0.0
# 1075358                      0.0                  0.0       0.0
#
# [5 rows x 50 columns]

# %%
data.columns
# Out:
# Index(['member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term',
#        'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title',
#        'emp_length', 'home_ownership', 'annual_inc', 'verification_status',
#        'issue_d', 'loan_status', 'url', 'desc', 'purpose', 'title', 'zip_code',
#        'addr_state', 'dti', 'delinq_2yrs', 'earliest_cr_line',
#        'inq_last_6mths', 'mths_since_last_delinq', 'mths_since_last_record',
#        'open_acc', 'pub_rec', 'revol_bal', 'revol_util', 'total_acc',
#        'out_prncp', 'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv',
#        'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee', 'recoveries',
#        'collection_recovery_fee', 'last_pymnt_d', 'last_pymnt_amnt',
#        'next_pymnt_d', 'last_credit_pull_d', 'collections_12_mths_ex_med',
#        'chargeoff_within_12_mths', 'pub_rec_bankruptcies', 'tax_liens'],
#       dtype='object')

# %%
single_valued_columns_list = []
for i in data.columns:
    if data[i].value_counts().shape[0]<=5:
        print(i, ' : ', data[i].unique())
        single_valued_columns_list.append(i)
# Out:
# term  :  [' 36 months' ' 60 months']
# home_ownership  :  ['RENT' 'OWN' 'MORTGAGE' 'OTHER' 'NONE']
# verification_status  :  ['Verified' 'Source Verified' 'Not Verified']
# loan_status  :  ['Fully Paid' 'Charged Off' 'Current']
# pub_rec  :  [0 1 2 3 4]
# next_pymnt_d  :  [nan 'Jun-16' 'Jul-16']
# collections_12_mths_ex_med  :  [ 0. nan]
# chargeoff_within_12_mths  :  [ 0. nan]
# pub_rec_bankruptcies  :  [ 0.  1.  2. nan]
# tax_liens  :  [ 0. nan]

# %%
data.next_pymnt_d.isna().sum()/data.shape[0]
# Out:
# 0.971296925749679

# %% [markdown]
# #### Next payment date column has 97% missing values and the the dates are Jun-16 and Jul-16 which are five years from 2011.
# #### So we don't need this column for analysis.

# %%
data.drop(['next_pymnt_d'], axis=1, inplace=True)

# %%
data.chargeoff_within_12_mths.isna().sum()/data.shape[0]
# Out:
# 0.0014099755772087519

# %% [markdown]
# #### Member id is just ID representing the customer there no significance of this column in the analysis

# %%
data.drop(['member_id'], axis=1, inplace=True)

# %%
data.emp_title.unique().shape[0]
# Out:
# 28821

# %% [markdown]
# #### There are 28K unique job titles, I don't think this is also helpfull for analysis

# %%
data.drop(['emp_title'], axis=1, inplace=True)

# %%
data.url
# Out:
# id
# 1077501    https://lendingclub.com/browse/loanDetail.acti...
# 1077430    https://lendingclub.com/browse/loanDetail.acti...
# 1077175    https://lendingclub.com/browse/loanDetail.acti...
# 1076863    https://lendingclub.com/browse/loanDetail.acti...
# 1075358    https://lendingclub.com/browse/loanDetail.acti...
#                                  ...
# 92187      https://lendingclub.com/browse/loanDetail.acti...
# 90665      https://lendingclub.com/browse/loanDetail.acti...
# 90395      https://lendingclub.com/browse/loanDetail.acti...
# 90376      https://lendingclub.com/browse/loanDetail.acti...
# 87023      https://lendingclub.com/browse/loanDetail.acti...
# Name: url, Length: 39717, dtype: object

# %% [markdown]
# #### url column seem to be the loan details of each id, so we don't neec this column also for analysis

# %%
data.drop(['url'], axis=1, inplace=True)

# %%
data[['purpose', 'title']]
# Out:
#                     purpose                      title
# id
# 1077501         credit_card                   Computer
# 1077430                 car                       bike
# 1077175      small_business       real estate business
# 1076863               other                   personel
# 1075358               other                   Personal
# ...                     ...                        ...
# 92187      home_improvement           Home Improvement
# 90665           credit_card  Retiring credit card debt
# 90395    debt_consolidation     MBA Loan Consolidation
# 90376                 other                   JAL Loan
# 87023    debt_consolidation         Consolidation Loan
#
# [39717 rows x 2 columns]

# %%
data.purpose.unique()
# Out:
# array(['credit_card', 'car', 'small_business', 'other', 'wedding',
#        'debt_consolidation', 'home_improvement', 'major_purchase',
#        'medical', 'moving', 'vacation', 'house', 'renewable_energy',
#        'educational'], dtype=object)

# %%
data.title.unique()
# Out:
# array(['Computer', 'bike', 'real estate business', ...,
#        'Retiring credit card debt', 'MBA Loan Consolidation', 'JAL Loan'],
#       dtype=object)

# %% [markdown]
# #### Title column is subcategory of purpose column, so Title column also not needed.

# %%
data.drop(['title'], axis=1, inplace=True)

# %%
data.zip_code.head()
# Out:
# id
# 1077501    860xx
# 1077430    309xx
# 1077175    606xx
# 1076863    917xx
# 1075358    972xx
# Name: zip_code, dtype: object

# %% [markdown]
# #### Zip code column might be required if we want to analyze defaulter from each area but there are more than 800 unique values are present in this column, so i am ignoring for now.

# %%
data.drop(['zip_code'], axis=1, inplace=True)

# %%
data.mths_since_last_record.isna().sum()/data.shape[0]
# Out:
# 0.9298537150338646

# %% [markdown]
# #### The number of months since the last public record. column has 92% missing values, so removing this columns

# %%
data.drop(['mths_since_last_record'], axis=1, inplace=True)

# %%
data.open_acc.unique()
# Out:
# array([ 3,  2, 10, 15,  9,  7,  4, 11, 14, 12, 20,  8,  6, 17,  5, 13, 16,
#        30, 21, 18, 19, 27, 23, 34, 25, 22, 24, 26, 32, 28, 29, 33, 31, 39,
#        35, 36, 38, 44, 41, 42], dtype=int64)

# %%
data.emp_length.fillna('Unknown', inplace=True)

# %%
data.pub_rec_bankruptcies.fillna('Unknown', inplace=True)

# %%
data.desc.isna().sum()/data.shape[0]
# Out:
# 0.3258050708764509

# %%
data.mths_since_last_delinq.isna().sum()/data.shape[0]
# Out:
# 0.6466248709620566

# %% [markdown]
# #### Most of the credit pull dates are 2013, 16 future dates. we need to find out if customer is potential defaulter or not before approving the loan. so droping this column

# %%
data.drop(['last_credit_pull_d'], axis=1, inplace=True)

# %% [markdown]
# #### Removing months since last delinq and desc column as they have more than 30% missing values

# %%
data.drop(['mths_since_last_delinq', 'desc'], axis=1, inplace=True)

# %%
msno.matrix(data.sample(50))
# Out:
# <AxesSubplot:>

# %%
msno.bar(data)
# Out:
# <AxesSubplot:>

# %%
data.shape
# Out:
# (39717, 40)

# %%
data.describe()
# Out:
#           loan_amnt   funded_amnt  funded_amnt_inv   installment  \
# count  39717.000000  39717.000000     39717.000000  39717.000000
# mean   11219.443815  10947.713196     10397.448868    324.561922
# std     7456.670694   7187.238670      7128.450439    208.874874
# min      500.000000    500.000000         0.000000     15.690000
# 25%     5500.000000   5400.000000      5000.000000    167.020000
# 50%    10000.000000   9600.000000      8975.000000    280.220000
# 75%    15000.000000  15000.000000     14400.000000    430.780000
# max    35000.000000  35000.000000     35000.000000   1305.190000
#
#          annual_inc           dti   delinq_2yrs  inq_last_6mths      open_acc  \
# count  3.971700e+04  39717.000000  39717.000000    39717.000000  39717.000000
# mean   6.896893e+04     13.315130      0.146512        0.869200      9.294408
# std    6.379377e+04      6.678594      0.491812        1.070219      4.400282
# min    4.000000e+03      0.000000      0.000000        0.000000      2.000000
# 25%    4.040400e+04      8.170000      0.000000        0.000000      6.000000
# 50%    5.900000e+04     13.400000      0.000000        1.000000      9.000000
# 75%    8.230000e+04     18.600000      0.000000        1.000000     12.000000
# max    6.000000e+06     29.990000     11.000000        8.000000     44.000000
#
#             pub_rec  ...  total_pymnt_inv  total_rec_prncp  total_rec_int  \
# count  39717.000000  ...     39717.000000     39717.000000   39717.000000
# mean       0.055065  ...     11567.149118      9793.348813    2263.663172
# std        0.237200  ...      8942.672613      7065.522127    2608.111964
# min        0.000000  ...         0.000000         0.000000       0.000000
# 25%        0.000000  ...      5112.310000      4600.000000     662.180000
# 50%        0.000000  ...      9287.150000      8000.000000    1348.910000
# 75%        0.000000  ...     15798.810000     13653.260000    2833.400000
# max        4.000000  ...     58563.680000     35000.020000   23563.680000
#
#        total_rec_late_fee    recoveries  collection_recovery_fee  \
# count        39717.000000  39717.000000             39717.000000
# mean             1.363015     95.221624                12.406112
# std              7.289979    688.744771               148.671593
# min              0.000000      0.000000                 0.000000
# 25%              0.000000      0.000000                 0.000000
# 50%              0.000000      0.000000                 0.000000
# 75%              0.000000      0.000000                 0.000000
# max            180.200000  29623.350000              7002.190000
#
#        last_pymnt_amnt  collections_12_mths_ex_med  chargeoff_within_12_mths  \
# count     39717.000000                     39661.0                   39661.0
# mean       2678.826162                         0.0                       0.0
# std        4447.136012                         0.0                       0.0
# min           0.000000                         0.0                       0.0
# 25%         218.680000                         0.0                       0.0
# 50%         546.140000                         0.0                       0.0
# 75%        3293.160000                         0.0                       0.0
# max       36115.200000                         0.0                       0.0
#
#        tax_liens
# count    39678.0
# mean         0.0
# std          0.0
# min          0.0
# 25%          0.0
# 50%          0.0
# 75%          0.0
# max          0.0
#
# [8 rows x 25 columns]

# %% [markdown]
# #### Collection_12_mths_ex_med, chargeoff_within_12_mths, tax_liens column values are 0 only we can drop these conlumns

# %%
data.drop(['collections_12_mths_ex_med', 'chargeoff_within_12_mths', 'tax_liens'], axis=1, inplace=True)

# %%
data.shape
# Out:
# (39717, 37)

# %%
sns.heatmap(data[['loan_amnt','funded_amnt','funded_amnt_inv']].corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### loan_amnt, funded_amnt, funded_amnt_inv columns are highly correlated and values are similar. we can drop funded_amnt and funded_amnt_inv

# %%
data.drop(['funded_amnt','funded_amnt_inv'], axis=1, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39717 entries, 1077501 to 87023
# Data columns (total 35 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   loan_amnt                39717 non-null  int64
#  1   term                     39717 non-null  object
#  2   int_rate                 39717 non-null  object
#  3   installment              39717 non-null  float64
#  4   grade                    39717 non-null  object
#  5   sub_grade                39717 non-null  object
#  6   emp_length               39717 non-null  object
#  7   home_ownership           39717 non-null  object
#  8   annual_inc               39717 non-null  float64
#  9   verification_status      39717 non-null  object
#  10  issue_d                  39717 non-null  object
#  11  loan_status              39717 non-null  object
#  12  purpose                  39717 non-null  object
#  13  addr_state               39717 non-null  object
#  14  dti                      39717 non-null  float64
#  15  delinq_2yrs              39717 non-null  int64
#  16  earliest_cr_line         39717 non-null  object
#  17  inq_last_6mths           39717 non-null  int64
#  18  open_acc                 39717 non-null  int64
#  19  pub_rec                  39717 non-null  int64
#  20  revol_bal                39717 non-null  int64
#  21  revol_util               39667 non-null  object
#  22  total_acc                39717 non-null  int64
#  23  out_prncp                39717 non-null  float64
#  24  out_prncp_inv            39717 non-null  float64
#  25  total_pymnt              39717 non-null  float64
#  26  total_pymnt_inv          39717 non-null  float64
#  27  total_rec_prncp          39717 non-null  float64
#  28  total_rec_int            39717 non-null  float64
#  29  total_rec_late_fee       39717 non-null  float64
#  30  recoveries               39717 non-null  float64
#  31  collection_recovery_fee  39717 non-null  float64
#  32  last_pymnt_d             39646 non-null  object
#  33  last_pymnt_amnt          39717 non-null  float64
#  34  pub_rec_bankruptcies     39717 non-null  object
# dtypes: float64(13), int64(7), object(15)
# memory usage: 10.9+ MB

# %%
cat_data = data[['loan_amnt','term','int_rate','grade','sub_grade','home_ownership','verification_status',
                'issue_d','loan_status','purpose','addr_state','earliest_cr_line','revol_util','last_pymnt_d',
                 'emp_length','pub_rec_bankruptcies']]

# %%
cat_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39717 entries, 1077501 to 87023
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   loan_amnt             39717 non-null  int64
#  1   term                  39717 non-null  object
#  2   int_rate              39717 non-null  object
#  3   grade                 39717 non-null  object
#  4   sub_grade             39717 non-null  object
#  5   home_ownership        39717 non-null  object
#  6   verification_status   39717 non-null  object
#  7   issue_d               39717 non-null  object
#  8   loan_status           39717 non-null  object
#  9   purpose               39717 non-null  object
#  10  addr_state            39717 non-null  object
#  11  earliest_cr_line      39717 non-null  object
#  12  revol_util            39667 non-null  object
#  13  last_pymnt_d          39646 non-null  object
#  14  emp_length            39717 non-null  object
#  15  pub_rec_bankruptcies  39717 non-null  object
# dtypes: int64(1), object(15)
# memory usage: 5.2+ MB

# %% [markdown]
# ## Lets Analyze the data and find the outliers and see if can derive new variables.

# %%
plt.figure(figsize=(10,7))
sns.boxplot(x=cat_data.loan_amnt)
# Out:
# <AxesSubplot:xlabel='loan_amnt'>

# %%
sns.histplot(x=cat_data.term)
# Out:
# <AxesSubplot:xlabel='term', ylabel='Count'>

# %%
plt.figure(figsize=(10,7))
sns.boxplot(x=cat_data.loan_amnt, y= cat_data.term, hue=cat_data.loan_status)
# Out:
# <AxesSubplot:xlabel='loan_amnt', ylabel='term'>

# %%
#Percentage of charged off
cat_data.loan_status.value_counts(normalize=True).plot.bar()
# Out:
# <AxesSubplot:>

# %%
# group by term months and check the percentage of charge off in each term
term = cat_data.groupby(['term'])['loan_status'].value_counts(normalize=True).unstack()
term.plot.bar(figsize=(10,7))
# Out:
# <AxesSubplot:xlabel='term'>

# %%
term
# Out:
# loan_status  Charged Off   Current  Fully Paid
# term
#  36 months      0.110909       NaN    0.889091
#  60 months      0.225967  0.107335    0.666698

# %% [markdown]
# #### Charges off are more in 60 months loan term only.

# %%
cat_data.int_rate = cat_data.int_rate.map(lambda x : float(x.strip('%')))
plt.figure(figsize=(10,7))
sns.barplot(y=cat_data.int_rate,x=cat_data.loan_status)
# Out:
# C:\Users\gtpra\AppData\Local\Temp\ipykernel_24496\1983941274.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cat_data.int_rate = cat_data.int_rate.map(lambda x : float(x.strip('%')))
# <AxesSubplot:xlabel='loan_status', ylabel='int_rate'>

# %%
sns.boxplot(x=cat_data.int_rate, y=cat_data.loan_status)
# Out:
# <AxesSubplot:xlabel='int_rate', ylabel='loan_status'>

# %% [markdown]
# #### Lets create bins of interest rate and check if interset rate is a factor of charge off

# %%
cat_data['int_ranges'] = pd.cut(x=cat_data['int_rate'], bins=[3.0, 6.0, 9.0, 12.0, 15.0, 18.0, 21.0, 25.0])
cat_data.groupby(['int_ranges'])['loan_status'].value_counts(normalize=True).unstack().plot.bar(figsize=(10,7))
# Out:
# C:\Users\gtpra\AppData\Local\Temp\ipykernel_24496\1569698240.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cat_data['int_ranges'] = pd.cut(x=cat_data['int_rate'], bins=[3.0, 6.0, 9.0, 12.0, 15.0, 18.0, 21.0, 25.0])
# <AxesSubplot:xlabel='int_ranges'>

# %% [markdown]
# #### Mostly of the charge off are happening if interst rate is high.

# %%
cat_data.groupby(['int_ranges'])['term'].value_counts(normalize=True).unstack().plot.bar(figsize=(10,7))
# Out:
# <AxesSubplot:xlabel='int_ranges'>

# %% [markdown]
# #### As interest rate increases percentage of 30 months term loans are decreasing and 60 months term loans are increasing.

# %% [markdown]
# #### We can clearly see if interest rate if more than 15% term of the loan with 60months is higher. It means they end up paying more interest hence charged off

# %% [markdown]
# #### Lets see if loan grade has any effect on charge off

# %%
plt.figure(figsize=(10,7))
sns.histplot(x=cat_data.grade, kde=True, hue=data.loan_status, multiple='dodge')
# Out:
# <AxesSubplot:xlabel='grade', ylabel='Count'>

# %%
cat_data.groupby(['grade'])['loan_status'].value_counts(normalize=True).unstack().plot.bar(figsize=(10,7))
# Out:
# <AxesSubplot:xlabel='grade'>

# %% [markdown]
# #### Grade B, C, D seems to have high number of charge offs

# %% [markdown]
# #### Lets see why some grade of loans have high charge off

# %%
cat_data.groupby(['grade'])['int_ranges'].value_counts().unstack()
# Out:
#        (3.0, 6.0]  (6.0, 9.0]  (9.0, 12.0]  (12.0, 15.0]  (15.0, 18.0]  \
# grade
# A            1331        8330          424             0             0
# B               5         172        10340          1503             0
# C               4           0          346          7141           607
# D               4           0            9          1520          3608
# E               4           0            0            54          1735
# F               0           0            0             0            67
# G               0           0            0             0             1
#
#        (18.0, 21.0]  (21.0, 25.0]
# grade
# A                 0             0
# B                 0             0
# C                 0             0
# D               166             0
# E              1049             0
# F               753           229
# G               154           161

# %% [markdown]
# #### Number of loan accounts with highest interest are high in Grade A, B, C, D

# %% [markdown]
# #### Lets see if loan sub-grade has any effect on charge off

# %%
plt.figure(figsize=(15,7))
sns.histplot(x=cat_data.sub_grade, kde=True, hue=cat_data.loan_status, multiple='dodge')
# Out:
# <AxesSubplot:xlabel='sub_grade', ylabel='Count'>

# %%
plt.figure(figsize=(10,7))
sns.histplot(x=cat_data.home_ownership, kde=True, hue=cat_data.loan_status, multiple='dodge')
# Out:
# <AxesSubplot:xlabel='home_ownership', ylabel='Count'>

# %%
cat_data.groupby(['home_ownership'])['loan_status'].value_counts(normalize=True).unstack().plot.bar(figsize=(10,7))
# Out:
# <AxesSubplot:xlabel='home_ownership'>

# %%
plt.figure(figsize=(15,10))
sns.boxplot(x=cat_data.home_ownership, y=cat_data.loan_amnt, hue=cat_data.loan_status)
# Out:
# <AxesSubplot:xlabel='home_ownership', ylabel='loan_amnt'>

# %%
plt.figure(figsize=(15,10))
sns.boxplot(x=cat_data.home_ownership, y=cat_data.int_rate, hue=cat_data.loan_status)
# Out:
# <AxesSubplot:xlabel='home_ownership', ylabel='int_rate'>

# %%
plt.figure(figsize=(15,10))
sns.boxplot(x=cat_data.home_ownership, y=cat_data.revol_util, hue=cat_data.loan_status)
# Out:
# <AxesSubplot:xlabel='home_ownership', ylabel='revol_util'>

# %%
house_status = cat_data.groupby(['home_ownership'])['loan_status'].value_counts(normalize=False).unstack()
house_status
# Out:
# loan_status     Charged Off  Current  Fully Paid
# home_ownership
# MORTGAGE             2327.0    638.0     14694.0
# NONE                    NaN      NaN         3.0
# OTHER                  18.0      NaN        80.0
# OWN                   443.0     83.0      2532.0
# RENT                 2839.0    419.0     15641.0

# %%
house_status.loc['RENT/MOR'] = house_status.loc['MORTGAGE'] + house_status.loc['RENT']
house_status.loc['OTHER/NONE'] = house_status.loc['OTHER'] + house_status.loc['NONE']
house_status = house_status.T.drop(columns=['MORTGAGE','RENT', 'OTHER','NONE'], axis=1).reset_index()
house_status.OWN = house_status.OWN/house_status.OWN.sum()
house_status['RENT/MOR'] = house_status['RENT/MOR']/house_status['RENT/MOR'].sum()
house_status['OTHER/NONE'] = house_status['OTHER/NONE']/house_status['OTHER/NONE'].sum()
house_status
# Out:
# home_ownership  loan_status       OWN  RENT/MOR  OTHER/NONE
# 0               Charged Off  0.144866  0.141310         NaN
# 1                   Current  0.027142  0.028913         NaN
# 2                Fully Paid  0.827992  0.829777         1.0

# %%
for i in range(1,len(house_status.columns)):
    sns.barplot(x=house_status.loan_status, y=house_status[house_status.columns[i]])
    plt.show()

# %% [markdown]
# #### Percentage of charge offs are almost same for RENT\MORTGAGE\OWN

# %% [markdown]
# #### Lets If loan purpose has any effect on charge off

# %%
plt.figure(figsize=(15,7))
plot = sns.histplot(cat_data.purpose)
plt.setp(plot.get_xticklabels(), rotation=90)
plt.show()

# %% [markdown]
# #### Large amount of loans are taken for debt consolidation.

# %%
plt.figure(figsize=(15,10))
plot = sns.histplot(x=cat_data.purpose, kde=True, hue=cat_data.loan_status, multiple='dodge')
plt.setp(plot.get_xticklabels(), rotation=90)
plt.show()

# %% [markdown]
# #### Number of Charge off are high in debt_consolidation loans only

# %%
for i in cat_data.purpose.unique():
    ax = cat_data[cat_data.purpose=='debt_consolidation']['int_ranges'].value_counts().plot.bar()
    ax.set(xlabel='Interest ranges', ylabel=i)
    plt.show()

# %% [markdown]
# #### Interest rates between 9 to 15 have high number of loans, 3 to 6 & and 21 to 25% loans are less number.

# %% [markdown]
# #### Lets see which type of loan has more percentage of charge off

# %%
purpose_data = cat_data.groupby(['purpose'])['loan_status'].value_counts(normalize=True).unstack()
purpose_data.plot.bar(figsize=(15, 10), color={"Charged Off": "red", "Current": "yellow", "Fully Paid":"green"})
# Out:
# <AxesSubplot:xlabel='purpose'>

# %% [markdown]
# #### By analysing the purpose of loan, we can tell Small business loans have highest percentage of charge off's compared to other

# %%
address_data = cat_data.groupby(['addr_state'])['loan_status'].value_counts(normalize=True).unstack()
address_data = address_data.sort_values(by='Charged Off', ascending=False).head(10)
address_data.plot.bar(figsize=(15, 10), color={"Charged Off": "red", "Current": "yellow", "Fully Paid":"green"})
plt.show()

# %% [markdown]
# #### NE has the highest percentage of charge off's compared to other states

# %%
address_data = cat_data.groupby(['addr_state'])['loan_status'].value_counts().unstack()
address_data = address_data.sort_values(by='Charged Off', ascending=False).head(10)
address_data.plot.bar(figsize=(15, 10), color={"Charged Off": "red", "Current": "yellow", "Fully Paid":"green"})
plt.show()

# %% [markdown]
# #### If we look at the number of charge off's in each state instead of percentage, CA has large number of charge off's

# %%
cat_data.earliest_cr_line.head()
def yearcon(x):
    dateti = datetime.strptime(x, '%b-%y')
    return dateti.year
def monthcon(x):
    dateti = datetime.strptime(x, '%b-%y')
    return dateti.month
cat_data['earliest_cr_line_year'] = cat_data.earliest_cr_line.map(yearcon)
# Out:
# C:\Users\gtpra\AppData\Local\Temp\ipykernel_24496\3752401277.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cat_data['earliest_cr_line_year'] = cat_data.earliest_cr_line.map(yearcon)

# %%
cat_data[cat_data['earliest_cr_line_year']>2011]['earliest_cr_line_year'].value_counts()
# Out:
# 2068    20
# 2067    18
# 2066    11
# 2063    10
# 2064     9
# 2065     9
# 2062     5
# 2054     2
# 2061     2
# 2059     1
# 2056     1
# 2046     1
# 2050     1
# Name: earliest_cr_line_year, dtype: int64

# %% [markdown]
# #### There are more than 60 rows with earliest credit line year mentioned as 2050, 67 etc. which are not valid as the dataset is taken from 2007 to 2011. this date should not be future dates.

# %%
cat_data[cat_data['earliest_cr_line_year']>2011]['loan_status'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
cat_data['earliest_cr_line_year'].min()
# Out:
# 1969

# %%
# Lets remove those rows and create bins for credit line years and see if earliest credit line has any effect on loan status
cr_data = cat_data[cat_data['earliest_cr_line_year']<2011]
cr_data['year_ranges'] = pd.cut(x=cr_data['earliest_cr_line_year'], bins=[1965,1975, 1985, 1995, 2005, 2011])
cr_data.groupby(['year_ranges'])['loan_status'].value_counts(normalize=True).unstack().plot.bar(figsize=(10,7))
# Out:
# C:\Users\gtpra\AppData\Local\Temp\ipykernel_24496\3337611269.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cr_data['year_ranges'] = pd.cut(x=cr_data['earliest_cr_line_year'], bins=[1965,1975, 1985, 1995, 2005, 2011])
# <AxesSubplot:xlabel='year_ranges'>

# %% [markdown]
# #### Earliest credit line from 2005 to 2011 have high slightly high rate of charge off

# %% [markdown]
# #### Lets See if issue data has any effect on loan status

# %%
cat_data['issue_date_format'] = cat_data.issue_d.map(lambda x : datetime.strptime(x, '%b-%y'))
cat_data.issue_date_format
# Out:
# C:\Users\gtpra\AppData\Local\Temp\ipykernel_24496\351187525.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cat_data['issue_date_format'] = cat_data.issue_d.map(lambda x : datetime.strptime(x, '%b-%y'))
# id
# 1077501   2011-12-01
# 1077430   2011-12-01
# 1077175   2011-12-01
# 1076863   2011-12-01
# 1075358   2011-12-01
#              ...
# 92187     2007-07-01
# 90665     2007-07-01
# 90395     2007-07-01
# 90376     2007-07-01
# 87023     2007-06-01
# Name: issue_date_format, Length: 39717, dtype: datetime64[ns]

# %%
date_format = cat_data.groupby(['issue_date_format'])['loan_status', 'term'].value_counts().unstack()
# Out:
# C:\Users\gtpra\AppData\Local\Temp\ipykernel_24496\1557923923.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   date_format = cat_data.groupby(['issue_date_format'])['loan_status', 'term'].value_counts().unstack()

# %%
plt.figure(figsize=(15, 10))
sns.lineplot(x=cat_data.issue_date_format, y=cat_data.int_rate, hue=cat_data.loan_status)
# Out:
# <AxesSubplot:xlabel='issue_date_format', ylabel='int_rate'>

# %%
plt.figure(figsize=(15, 10))
issue_data = cat_data.groupby(['issue_date_format'])['loan_status'].value_counts(normalize=True).unstack()
sns.lineplot(x=issue_data.index, y=issue_data['Charged Off'])
sns.lineplot(x=issue_data.index, y=issue_data['Fully Paid'])
sns.lineplot(x=issue_data.index, y=issue_data['Current'])
# Out:
# <AxesSubplot:xlabel='issue_date_format', ylabel='Charged Off'>

# %%
plt.figure(figsize=(15, 10))
sns.lineplot(x=cat_data.issue_date_format, y=cat_data.loan_amnt, hue=cat_data.loan_status)
# Out:
# <AxesSubplot:xlabel='issue_date_format', ylabel='loan_amnt'>

# %%
plt.figure(figsize=(15, 10))
sns.lineplot(x=cat_data.issue_date_format, y=cat_data.revol_util, hue=cat_data.loan_status)
# Out:
# <AxesSubplot:xlabel='issue_date_format', ylabel='revol_util'>

# %%
issue_data = cat_data.groupby(['issue_date_format', 'loan_status'])['term'].value_counts().unstack().reset_index()
plt.figure(figsize=(15, 10))
sns.lineplot(x=issue_data.issue_date_format, y=issue_data[' 36 months'], hue=issue_data.loan_status)
# Out:
# <AxesSubplot:xlabel='issue_date_format', ylabel=' 36 months'>

# %%
plt.figure(figsize=(15, 10))
sns.lineplot(x=issue_data.issue_date_format, y=issue_data[' 60 months'], hue=issue_data.loan_status)
# Out:
# <AxesSubplot:xlabel='issue_date_format', ylabel=' 60 months'>

# %%
issue_data = cat_data.groupby(['issue_date_format'])['verification_status'].value_counts().unstack()
plt.figure(figsize=(15, 10))
sns.lineplot(x=issue_data.index, y=issue_data['Not Verified'])
sns.lineplot(x=issue_data.index, y=issue_data['Source Verified'])
sns.lineplot(x=issue_data.index, y=issue_data['Verified'])
issue_data.columns
# Out:
# Index(['Not Verified', 'Source Verified', 'Verified'], dtype='object', name='verification_status')

# %%
cat_data['issue_year'] = cat_data.issue_d.map(yearcon)
cat_data['issue_month'] = cat_data.issue_d.map(monthcon)
plt.figure(figsize=(15,10))
sns.boxplot(x=cat_data.issue_year, y=cat_data.int_rate, hue=cat_data.loan_status)
# Out:
# C:\Users\gtpra\AppData\Local\Temp\ipykernel_24496\2615496117.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cat_data['issue_year'] = cat_data.issue_d.map(yearcon)
# C:\Users\gtpra\AppData\Local\Temp\ipykernel_24496\2615496117.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cat_data['issue_month'] = cat_data.issue_d.map(monthcon)
# <AxesSubplot:xlabel='issue_year', ylabel='int_rate'>

# %%
plt.figure(figsize=(15, 10))
sns.boxplot(x=cat_data.issue_year, y=cat_data.loan_amnt, hue=cat_data.loan_status)
# Out:
# <AxesSubplot:xlabel='issue_year', ylabel='loan_amnt'>

# %%
verification_data = cat_data.groupby(['verification_status'])['loan_status'].value_counts().unstack()
verification_data = verification_data.sort_values(by='Charged Off', ascending=False).head(10)
verification_data.plot.bar(figsize=(15, 10), color={"Charged Off": "red", "Current": "yellow", "Fully Paid":"green"})
plt.show()

# %%
verification_data = cat_data.groupby(['verification_status'])['loan_status'].value_counts(normalize=True).unstack()
verification_data = verification_data.sort_values(by='Charged Off', ascending=False).head(10)
verification_data.plot.bar(figsize=(15, 10), color={"Charged Off": "red", "Current": "yellow", "Fully Paid":"green"})
plt.show()

# %%
verification_data = cat_data.groupby(['verification_status'])['pub_rec_bankruptcies'].value_counts(normalize=True).unstack()
verification_data
# Out:
# pub_rec_bankruptcies       0.0       1.0       2.0   Unknown
# verification_status
# Not Verified          0.915076  0.043733  0.000059  0.041132
# Source Verified       0.958847  0.040753  0.000401       NaN
# Verified              0.958623  0.041143  0.000156  0.000078

# %%
verification_data.plot.bar(figsize=(15, 10))
plt.show()

# %%
cat_data.revol_util = cat_data.revol_util.map(lambda x : float(x.strip('%')) if isinstance(x, str) else x)
cat_data.revol_util.isna().value_counts()
# Out:
# C:\Users\gtpra\AppData\Local\Temp\ipykernel_24496\4115380857.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cat_data.revol_util = cat_data.revol_util.map(lambda x : float(x.strip('%')) if isinstance(x, str) else x)
# False    39667
# True        50
# Name: revol_util, dtype: int64

# %%
sns.boxplot(x=cat_data.revol_util)
# Out:
# <AxesSubplot:xlabel='revol_util'>

# %%
#### fillna in revol_util column withe median
cat_data.revol_util.fillna(value=cat_data.revol_util.median(), inplace=True)
# Out:
# C:\Users\gtpra\AppData\Local\Temp\ipykernel_24496\694688382.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cat_data.revol_util.fillna(value=cat_data.revol_util.median(), inplace=True)

# %%
plt.figure(figsize=(15,10))
sns.histplot(x=cat_data.revol_util, hue=data.loan_status, multiple='dodge')
# Out:
# <AxesSubplot:xlabel='revol_util', ylabel='Count'>

# %%
plt.figure(figsize=(15,10))
sns.boxplot(x=cat_data.revol_util, y=cat_data.loan_status)
# Out:
# <AxesSubplot:xlabel='revol_util', ylabel='loan_status'>

# %%
cat_data.pub_rec_bankruptcies = cat_data.pub_rec_bankruptcies.map(lambda x : str(x))
cat_data.groupby(['pub_rec_bankruptcies'])['loan_status'].value_counts(normalize=True).unstack().plot.bar()
# Out:
# C:\Users\gtpra\AppData\Local\Temp\ipykernel_24496\3505019077.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cat_data.pub_rec_bankruptcies = cat_data.pub_rec_bankruptcies.map(lambda x : str(x))
# <AxesSubplot:xlabel='pub_rec_bankruptcies'>

# %%
plt.figure(figsize=(15,10))
sns.histplot(x=cat_data.pub_rec_bankruptcies, hue=data.loan_status, multiple='dodge')
# Out:
# <AxesSubplot:xlabel='pub_rec_bankruptcies', ylabel='Count'>

# %%
plt.figure(figsize=(15,10))
sns.boxplot(x=cat_data.pub_rec_bankruptcies, y=cat_data.int_rate, hue=cat_data.loan_status)
# Out:
# <AxesSubplot:xlabel='pub_rec_bankruptcies', ylabel='int_rate'>

# %%
plt.figure(figsize=(15,10))
sns.boxplot(x=cat_data.pub_rec_bankruptcies, y=cat_data.loan_amnt, hue=cat_data.loan_status)
# Out:
# <AxesSubplot:xlabel='pub_rec_bankruptcies', ylabel='loan_amnt'>

# %%
cat_data.sort_values(by='last_pymnt_d').last_pymnt_d.value_counts()
# Out:
# May-16    1256
# Mar-13    1026
# Dec-14     945
# May-13     907
# Feb-13     869
#           ...
# Nov-08      10
# Jun-08      10
# Mar-08       5
# Jan-08       4
# Feb-08       1
# Name: last_pymnt_d, Length: 101, dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.histplot(x=cat_data.emp_length, hue=data.loan_status, multiple='dodge')
# Out:
# <AxesSubplot:xlabel='emp_length', ylabel='Count'>

# %%
employee_data = cat_data.groupby(['emp_length'])['loan_status'].value_counts(normalize=True).unstack()
employee_data = employee_data.sort_values(by='Charged Off', ascending=False).head(10)
employee_data.plot.bar(figsize=(15, 10), color={"Charged Off": "red", "Current": "yellow", "Fully Paid":"green"})
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.boxplot(x=cat_data.emp_length, y=cat_data.int_rate, hue=cat_data.loan_status)
# Out:
# <AxesSubplot:xlabel='emp_length', ylabel='int_rate'>

# %%
# Out:
# <AxesSubplot:xlabel='issue_year', ylabel='loan_amnt'>
