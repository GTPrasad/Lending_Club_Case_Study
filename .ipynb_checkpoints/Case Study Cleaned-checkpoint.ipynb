# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.patches as mpatches

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
df =pd.read_csv('loan.csv')
# Out:
# C:\Users\U385998\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (47) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.shape
# Out:
# (39717, 111)

# %% [markdown]
# ### Data Exploration and Cleaning
#
# In this section we are:
#
# 1. Removing records with loan status "Current" as they don't help in determining if a loan will default or not
# 2. Cleaning the data based on null values
# 3. Removing the customer behavior metrics that we don't have during loan application

# %%
# Removing loans which are currently in progress 
df=df.loc[df.loan_status !='Current']

# %%
### Checking null values
nulls =df.isnull().sum()
nulls
# Out:
# id                                    0
# member_id                             0
# loan_amnt                             0
# funded_amnt                           0
# funded_amnt_inv                       0
# term                                  0
# int_rate                              0
# installment                           0
# grade                                 0
# sub_grade                             0
# emp_title                          2386
# emp_length                         1033
# home_ownership                        0
# annual_inc                            0
# verification_status                   0
# issue_d                               0
# loan_status                           0
# pymnt_plan                            0
# url                                   0
# desc                              12527
# purpose                               0
# title                                11
# zip_code                              0
# addr_state                            0
# dti                                   0
# delinq_2yrs                           0
# earliest_cr_line                      0
# inq_last_6mths                        0
# mths_since_last_delinq            24905
# mths_since_last_record            35837
# open_acc                              0
# pub_rec                               0
# revol_bal                             0
# revol_util                           50
# total_acc                             0
# initial_list_status                   0
# out_prncp                             0
# out_prncp_inv                         0
# total_pymnt                           0
# total_pymnt_inv                       0
# total_rec_prncp                       0
# total_rec_int                         0
# total_rec_late_fee                    0
# recoveries                            0
# collection_recovery_fee               0
# last_pymnt_d                         71
# last_pymnt_amnt                       0
# next_pymnt_d                      38577
# last_credit_pull_d                    2
# collections_12_mths_ex_med           56
# mths_since_last_major_derog       38577
# policy_code                           0
# application_type                      0
# annual_inc_joint                  38577
# dti_joint                         38577
# verification_status_joint         38577
# acc_now_delinq                        0
# tot_coll_amt                      38577
# tot_cur_bal                       38577
# open_acc_6m                       38577
# open_il_6m                        38577
# open_il_12m                       38577
# open_il_24m                       38577
# mths_since_rcnt_il                38577
# total_bal_il                      38577
# il_util                           38577
# open_rv_12m                       38577
# open_rv_24m                       38577
# max_bal_bc                        38577
# all_util                          38577
# total_rev_hi_lim                  38577
# inq_fi                            38577
# total_cu_tl                       38577
# inq_last_12m                      38577
# acc_open_past_24mths              38577
# avg_cur_bal                       38577
# bc_open_to_buy                    38577
# bc_util                           38577
# chargeoff_within_12_mths             56
# delinq_amnt                           0
# mo_sin_old_il_acct                38577
# mo_sin_old_rev_tl_op              38577
# mo_sin_rcnt_rev_tl_op             38577
# mo_sin_rcnt_tl                    38577
# mort_acc                          38577
# mths_since_recent_bc              38577
# mths_since_recent_bc_dlq          38577
# mths_since_recent_inq             38577
# mths_since_recent_revol_delinq    38577
# num_accts_ever_120_pd             38577
# num_actv_bc_tl                    38577
# num_actv_rev_tl                   38577
# num_bc_sats                       38577
# num_bc_tl                         38577
# num_il_tl                         38577
# num_op_rev_tl                     38577
# num_rev_accts                     38577
# num_rev_tl_bal_gt_0               38577
# num_sats                          38577
# num_tl_120dpd_2m                  38577
# num_tl_30dpd                      38577
# num_tl_90g_dpd_24m                38577
# num_tl_op_past_12m                38577
# pct_tl_nvr_dlq                    38577
# percent_bc_gt_75                  38577
# pub_rec_bankruptcies                697
# tax_liens                            39
# tot_hi_cred_lim                   38577
# total_bal_ex_mort                 38577
# total_bc_limit                    38577
# total_il_high_credit_limit        38577
# dtype: int64

# %%
## Removing columns with high null rate, over 80%

null_cols =list(nulls[nulls >= 0.8*len(df)].index)
not_null_cols =[i for i in df.columns if i not in null_cols]
df =df[not_null_cols]

# %%
df.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title',
#        'emp_length', 'home_ownership', 'annual_inc', 'verification_status',
#        'issue_d', 'loan_status', 'pymnt_plan', 'url', 'desc', 'purpose',
#        'title', 'zip_code', 'addr_state', 'dti', 'delinq_2yrs',
#        'earliest_cr_line', 'inq_last_6mths', 'mths_since_last_delinq',
#        'open_acc', 'pub_rec', 'revol_bal', 'revol_util', 'total_acc',
#        'initial_list_status', 'out_prncp', 'out_prncp_inv', 'total_pymnt',
#        'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_d', 'last_pymnt_amnt', 'last_credit_pull_d',
#        'collections_12_mths_ex_med', 'policy_code', 'application_type',
#        'acc_now_delinq', 'chargeoff_within_12_mths', 'delinq_amnt',
#        'pub_rec_bankruptcies', 'tax_liens'],
#       dtype='object')

# %%
# Removing Customer behavior columns 

df.drop(columns =['delinq_2yrs','earliest_cr_line', 'inq_last_6mths',
       'open_acc', 'pub_rec', 'revol_bal', 'revol_util', 'total_acc', 'out_prncp', 'out_prncp_inv', 'total_pymnt',
       'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
       'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
       'last_pymnt_d', 'last_pymnt_amnt','last_credit_pull_d','application_type'], inplace =True)
# Out:
# C:\Users\U385998\Anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df.shape
# Out:
# (38577, 34)

# %% [markdown]
# #### Analyzing Categorical Columns

# %%
cat_cols =[i for i in df.columns if df[i].dtype =='object']

# %%
## Getting the count of unique values for the categorical columns
cat_cols_nunique= {i: df[i].nunique() for i in cat_cols}
cat_cols_nunique
# Out:
# {'term': 2,
#  'int_rate': 370,
#  'grade': 7,
#  'sub_grade': 35,
#  'emp_title': 28027,
#  'emp_length': 11,
#  'home_ownership': 5,
#  'verification_status': 3,
#  'issue_d': 55,
#  'loan_status': 2,
#  'pymnt_plan': 1,
#  'url': 38577,
#  'desc': 25803,
#  'purpose': 14,
#  'title': 19297,
#  'zip_code': 822,
#  'addr_state': 50,
#  'initial_list_status': 1}

# %%
# Removing columns with only one cardinal value 
df.drop(columns =['pymnt_plan','initial_list_status'], inplace=True)

# Removing columns with very high cardinality
df.drop(columns =['emp_title','url','title','desc','zip_code'], inplace =True)

# %%
df.shape
# Out:
# (38577, 27)

# %%
# Data Type processing 

# Converting Interest rate to float values
df['int_rate'] =df['int_rate'].str.replace("%",'').astype('float')

# # Converting object date columns to date
df['issue_d'] =pd.to_datetime(df['issue_d'],format='%b-%y')

# Converting Term to int
df['term']=df['term'].str.replace(' months', '').astype('int')
# Out:
# C:\Users\U385998\AppData\Local\Temp/ipykernel_101360/1446780006.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['int_rate'] =df['int_rate'].str.replace("%",'').astype('float')
# C:\Users\U385998\AppData\Local\Temp/ipykernel_101360/1446780006.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['issue_d'] =pd.to_datetime(df['issue_d'],format='%b-%y')
# C:\Users\U385998\AppData\Local\Temp/ipykernel_101360/1446780006.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['term']=df['term'].str.replace(' months', '').astype('int')

# %% [markdown]
# ### Analyzing Continous Variables

# %%
cont_cols =[i for i in df.columns if (df[i].dtype == 'int64' or df[i].dtype =='float64') ]

# %%
df[cont_cols].describe()
# Out:
#                id   member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# count   38577.000   38577.000  38577.000    38577.000        38577.000
# mean   676378.707  842284.337  11047.025    10784.059        10222.481
# std    209263.898  264451.929   7348.442     7090.306         7022.721
# min     54734.000   70699.000    500.000      500.000            0.000
# 25%    512033.000  661131.000   5300.000     5200.000         5000.000
# 50%    656423.000  839292.000   9600.000     9550.000         8733.440
# 75%    829146.000 1037336.000  15000.000    15000.000        14000.000
# max   1077501.000 1314167.000  35000.000    35000.000        35000.000
#
#        int_rate  installment  annual_inc       dti  mths_since_last_delinq  \
# count 38577.000    38577.000   38577.000 38577.000               13672.000
# mean     11.932      322.466   68777.974    13.273                  35.883
# std       3.691      208.639   64218.682     6.673                  22.028
# min       5.420       15.690    4000.000     0.000                   0.000
# 25%       8.940      165.740   40000.000     8.130                  18.000
# 50%      11.710      277.860   58868.000    13.370                  34.000
# 75%      14.380      425.550   82000.000    18.560                  52.000
# max      24.400     1305.190 6000000.000    29.990                 120.000
#
#        collections_12_mths_ex_med  policy_code  acc_now_delinq  \
# count                   38521.000    38577.000       38577.000
# mean                        0.000        1.000           0.000
# std                         0.000        0.000           0.000
# min                         0.000        1.000           0.000
# 25%                         0.000        1.000           0.000
# 50%                         0.000        1.000           0.000
# 75%                         0.000        1.000           0.000
# max                         0.000        1.000           0.000
#
#        chargeoff_within_12_mths  delinq_amnt  pub_rec_bankruptcies  tax_liens
# count                 38521.000    38577.000             37880.000  38538.000
# mean                      0.000        0.000                 0.043      0.000
# std                       0.000        0.000                 0.205      0.000
# min                       0.000        0.000                 0.000      0.000
# 25%                       0.000        0.000                 0.000      0.000
# 50%                       0.000        0.000                 0.000      0.000
# 75%                       0.000        0.000                 0.000      0.000
# max                       0.000        0.000                 2.000      0.000

# %%
# Removing continous variables that have only 0 values and ids 

df.drop(columns=['id','member_id','policy_code','acc_now_delinq','collections_12_mths_ex_med','chargeoff_within_12_mths','delinq_amnt','tax_liens'], inplace=True)
# Out:
# C:\Users\U385998\Anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df.shape
# Out:
# (38577, 19)

# %% [markdown]
# #### Univariate Analysis - Continous Variables

# %%
cont_cols = [ i for i in df.columns if i in cont_cols]

# %%
for i in cont_cols:
    plt.figure(figsize=(12,5))
    plt.subplot(1,2,1)
    sns.histplot(x=df[i], kde=True)
    plt.subplot(1,2,2)
    sns.boxplot(x='loan_status',y=i,data=df)

# %% [markdown]
# Insights:
#
# 1. Int_rate: Charged off loans have on average higher interest rate than the fully paid loans, if the interest rate is higher than ~14%, the chances of charge off are very high
# 4. A lot of features are quite skewed including annual income

# %% [markdown]
# #### Outlier Treatment

# %%
# Treating Outliers in annual income
# Imputing values higher than the 99th percentile to the 99th percentile value
income_99 =df['annual_inc'].quantile(0.99)
df['annual_inc_treated'] =df['annual_inc'].apply(lambda x: x if x<=income_99 else income_99 )
# Out:
# C:\Users\U385998\AppData\Local\Temp/ipykernel_101360/2753743498.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['annual_inc_treated'] =df['annual_inc'].apply(lambda x: x if x<=income_99 else income_99 )

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
sns.histplot(x=df['annual_inc_treated'], kde=True)
plt.subplot(1,2,2)
sns.boxplot(x='loan_status',y='annual_inc_treated',data=df)
# Out:
# <AxesSubplot:xlabel='loan_status', ylabel='annual_inc_treated'>

# %%
# Treating Outliers in installment
# Imputing values higher than the 99th percentile to the 99th percentile value
installment_99 =df['installment'].quantile(0.99)
df['installment_treated'] =df['installment'].apply(lambda x: x if x<=installment_99 else installment_99 )

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
sns.histplot(x=df['installment_treated'], kde=True)
plt.subplot(1,2,2)
sns.boxplot(x='loan_status',y='installment_treated',data=df)
# Out:
# <AxesSubplot:xlabel='loan_status', ylabel='installment_treated'>

# %% [markdown]
# ### Feature Engineering
#
# Deriving new features from the data as per the understanding

# %%
df['monthly_income'] =round(df['annual_inc_treated']/12)
df['installment_monthly_income_prcnt'] =round((df['installment_treated']/df['monthly_income'])*100,2)

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
sns.histplot(x=df['installment_monthly_income_prcnt'], kde=True)
plt.subplot(1,2,2)
sns.boxplot(x='loan_status',y='installment_monthly_income_prcnt',data=df)
# Out:
# <AxesSubplot:xlabel='loan_status', ylabel='installment_monthly_income_prcnt'>

# %%
df['loan_amount_flag'] =df[['loan_amnt','funded_amnt_inv']].apply(lambda x: 1 if (x.loan_amnt -x.funded_amnt_inv)>50 else 0, axis=1)

# %%
df['loan_amount_diff'] =df['loan_amnt']-df['funded_amnt_inv']

# %%
df['loan_amount_diff'].describe()
# Out:
# count   38577.000
# mean      824.544
# std      2552.116
# min         0.000
# 25%         0.000
# 50%         6.004
# 75%       225.000
# max     32474.996
# Name: loan_amount_diff, dtype: float64

# %%
df['loan_amount_diff'].quantile(0.65)
# Out:
# 50.0

# %%
df[df.loan_amount_flag ==1 ].head()
# Out:
#     loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  installment  \
# 0        5000         5000         4975.000    36    10.650      162.870
# 9        5375         5375         5350.000    60    12.690      121.450
# 20      20250        20250        19142.161    60    15.270      484.630
# 26      15000        15000         8725.000    36    14.270      514.640
# 51      25600        25600        25350.000    36     9.910      824.960
#
#    grade sub_grade emp_length home_ownership  annual_inc verification_status  \
# 0      B        B2  10+ years           RENT   24000.000            Verified
# 9      B        B5   < 1 year           RENT   15000.000            Verified
# 20     C        C4    3 years           RENT   43370.000            Verified
# 26     C        C2    9 years           RENT   60000.000        Not Verified
# 51     B        B1    9 years           RENT  110000.000            Verified
#
#       issue_d  loan_status             purpose addr_state    dti  \
# 0  2011-12-01   Fully Paid         credit_card         AZ 27.650
# 9  2011-12-01  Charged Off               other         TX 18.080
# 20 2011-12-01   Fully Paid  debt_consolidation         TX 26.530
# 26 2011-12-01  Charged Off  debt_consolidation         NY 15.220
# 51 2011-12-01   Fully Paid         credit_card         CA 15.710
#
#     mths_since_last_delinq  pub_rec_bankruptcies  annual_inc_treated  \
# 0                      NaN                 0.000           24000.000
# 9                      NaN                 0.000           15000.000
# 20                     NaN                 0.000           43370.000
# 26                     NaN                 0.000           60000.000
# 51                     NaN                 0.000          110000.000
#
#     monthly_income  installment_monthly_income_prcnt  installment_treated  \
# 0         2000.000                             8.140              162.870
# 9         1250.000                             9.720              121.450
# 20        3614.000                            13.410              484.630
# 26        5000.000                            10.290              514.640
# 51        9167.000                             9.000              824.960
#
#     loan_amount_flag
# 0                  1
# 9                  1
# 20                 1
# 26                 1
# 51                 1

# %%
df.groupby('loan_amount_flag')['loan_status'].value_counts(normalize =True).unstack()
# Out:
# loan_status       Charged Off  Fully Paid
# loan_amount_flag
# 0                       0.145       0.855
# 1                       0.147       0.853

# %% [markdown]
# Insight: If the Installment to Monthly income percentage is more than ~8%, the chances of chargeoff increases

# %% [markdown]
# ### Bivariate and Segmented Analysis

# %%
# Studying Correlation between features 

plt.figure(figsize=(18,10))
sns.heatmap(df.corr(),annot=True, cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
# Features having very high correlation

# loan amount- funded amount, funded amount_inv, total_payment, installment
# total_payment - total_payment_inv,total_rec_prncp
# out_prncp -out_prncp_inv

# Removing some highly correlated features conservatively
df.drop(columns =['funded_amnt', 'funded_amnt_inv','total_pymnt_inv','total_rec_prncp','out_prncp_inv'], inplace =True)

# %%
df.shape
# Out:
# (39717, 39)

# %% [markdown]
# #### Analyzing features created

# %%
# Analyzing last payment flag

df.groupby(['last_payment_amount_flag'])['loan_status'].value_counts(normalize=True).unstack().plot.bar(figsize=(8,5))

# Insight: If the last paid amount is anytime higher than the installment, the customer has very less probability of Charging off
# Out:
# <AxesSubplot:xlabel='last_payment_amount_flag'>

# %%
# Analyzing total_rec_late_fee_flag
df.groupby(['total_rec_late_fee_flag'])['loan_status'].value_counts(normalize=True).unstack().plot.bar(figsize=(8,5))

# Insight: If there has been any late fees, the chances of Charging off increases
# Out:
# <AxesSubplot:xlabel='total_rec_late_fee_flag'>
